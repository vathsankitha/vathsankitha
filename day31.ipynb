# %% [markdown]
# <a href="https://colab.research.google.com/github/vathsankitha/vathsankitha/blob/main/day31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/energy_data_india_coYOUOMGWA.csv')
df.head()
# Out:
#    Household_ID Region  Monthly_Income_INR  Appliance_AC  Appliance_Fan  \
# 0             1  North               30000             1              3
# 1             2  South               45000             2              4
# 2             3   East               25000             0              2
# 3             4   West               60000             3              5
# 4             5  South               40000             1              3
#
#    Appliance_Light  Fridge  Washing_Machine  EV_Charging  \
# 0                6       1                0            0
# 1                8       1                1            1
# 2                5       1                0            0
# 3               10       2                1            1
# 4                7       1                0            0
#
#    Monthly_Energy_Consumption_kWh
# 0                             120
# 1                             210
# 2                              90
# 3                             320
# 4                             150

# %%
# Steps for Todays Project
# 1.Basic code shared below.. Candidates can add more features like user authentication, advanced analytics, or real-time data updates.
# 2.Improve the UI/UX of the dashboard for better user engagement.
# 3.Use Render to Upload the Project
# 4.Upload Project on GitHub https://github.com/yourusername/your-repo
#
# Project
# Smart Energy Consumption Dashboard (Additional Enhancement to be made my candidates)
# import all the libraries

import streamlit as st  # Frontend framework for building web apps
import pandas as pd     # Data manipulation and analysis
import matplotlib.pyplot as plt  # Data visualization
import seaborn as sns  # Statistical data visualization

# Step 1: Load dataset
# Load dataset
df = pd.read_csv("/content/energy_data_india_coYOUOMGWA.csv")

st.title("Energy Dashboard for Housing Complex")

# Step 2: Create Sidebar Filters
# Sidebar Filters
region = st.sidebar.selectbox("Select Region", ["All"] + sorted(df["Region"].unique().tolist()))

if region != "All":
    df = df[df["Region"] == region]

st.subheader(" Household Energy Consumption Overview")
st.write(df.head())

# Step 3: Metrics
avg_energy = df["Monthly_Energy_Consumption_kWh"].mean()
total_energy = df["Monthly_Energy_Consumption_kWh"].sum()
st.metric("Average Monthly Consumption (kWh)", f"{avg_energy:.2f}")
st.metric("Total Energy Consumption (kWh)", f"{total_energy:.0f}")

# Step 4: Visualizations
# Energy vs Income
st.subheader(" Income vs Energy Consumption")
fig1, ax1 = plt.subplots()
sns.scatterplot(data=df, x="Monthly_Income_INR", y="Monthly_Energy_Consumption_kWh", hue="Region", ax=ax1)
st.pyplot(fig1)

# Appliance Contribution
st.subheader(" Appliance-wise Count vs Energy Consumption")
appliances = ["Appliance_AC", "Appliance_Fan", "Appliance_Light", "Fridge", "Washing_Machine", "EV_Charging"]
selected_appliance = st.selectbox("Select Appliance", appliances)
fig2, ax2 = plt.subplots()
sns.barplot(x=df[selected_appliance], y=df["Monthly_Energy_Consumption_kWh"], ax=ax2)
ax2.set_xlabel(f"No. of {selected_appliance.replace('_', ' ')}")
ax2.set_ylabel("Energy Consumption (kWh)")
st.pyplot(fig2)

# Step 5: Recommendations
st.subheader(" Smart Recommendations")
for _, row in df.iterrows():
    if row["Monthly_Energy_Consumption_kWh"] > 250:
        st.warning(f"Household ID {row['Household_ID']} - High usage! Recommend switching to solar and LED bulbs.")
    elif row["EV_Charging"] == 1:
        st.info(f"Household ID {row['Household_ID']} - Consider installing a separate EV meter for optimal billing.")

# Step 6: Download Recommendations
# For Candidates Create a download link for the recommendations
recommendations = []
for _, row in df.iterrows():
    if row["Monthly_Energy_Consumption_kWh"] > 250:
        recommendations.append(f"Household ID {row['Household_ID']} - High usage! Recommend switching to solar and LED bulbs.")
    elif row["EV_Charging"] == 1:
        recommendations.append(f"Household ID {row['Household_ID']} - Consider installing a separate EV meter for optimal billing.")

if recommendations:
    st.download_button("Download Recommendations", "\n".join(recommendations), "recommendations.txt")

# Step 7: Conclusion to be added by Candidates
# Candidates can add More :: CSS, Graphs, ML models
# Out:
# 2025-07-31 09:35:04.267 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.347
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-07-31 09:35:04.348 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.349 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.356 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.358 Session state does not function when running a script without `streamlit run`
# 2025-07-31 09:35:04.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.362 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.363 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.364 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.404 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.405 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.414 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.415 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.416 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.418 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.680 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.682 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.683 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.921 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 09:35:04.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.47.1-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<26,>=20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.14.1)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 357.6 kB/s eta 0:00:00
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.45)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (4.25.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (1.48.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2025.7.14)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.26.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.47.1-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 15.8 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 35.9 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.3 MB/s eta 0:00:00
# Installing collected packages: watchdog, pydeck, streamlit
# Successfully installed pydeck-0.9.1 streamlit-1.47.1 watchdog-6.0.0

# %%
display(df.info())
display(df.isnull().sum())
display(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Household_ID                    10 non-null     int64
#  1   Region                          10 non-null     object
#  2   Monthly_Income_INR              10 non-null     int64
#  3   Appliance_AC                    10 non-null     int64
#  4   Appliance_Fan                   10 non-null     int64
#  5   Appliance_Light                 10 non-null     int64
#  6   Fridge                          10 non-null     int64
#  7   Washing_Machine                 10 non-null     int64
#  8   EV_Charging                     10 non-null     int64
#  9   Monthly_Energy_Consumption_kWh  10 non-null     int64
# dtypes: int64(9), object(1)
# memory usage: 932.0+ bytes
# None
# Household_ID                      0
# Region                            0
# Monthly_Income_INR                0
# Appliance_AC                      0
# Appliance_Fan                     0
# Appliance_Light                   0
# Fridge                            0
# Washing_Machine                   0
# EV_Charging                       0
# Monthly_Energy_Consumption_kWh    0
# dtype: int64
#        Household_ID  Monthly_Income_INR  Appliance_AC  Appliance_Fan  \
# count      10.00000           10.000000     10.000000      10.000000
# mean        5.50000        40000.000000      1.100000       3.200000
# std         3.02765        11690.451945      0.994429       1.032796
# min         1.00000        25000.000000      0.000000       2.000000
# 25%         3.25000        30250.000000      0.250000       2.250000
# 50%         5.50000        39000.000000      1.000000       3.000000
# 75%         7.75000        46500.000000      1.750000       4.000000
# max        10.00000        60000.000000      3.000000       5.000000
#
#        Appliance_Light     Fridge  Washing_Machine  EV_Charging  \
# count        10.000000  10.000000        10.000000    10.000000
# mean          6.700000   1.200000         0.500000     0.300000
# std           1.888562   0.421637         0.527046     0.483046
# min           4.000000   1.000000         0.000000     0.000000
# 25%           5.250000   1.000000         0.000000     0.000000
# 50%           6.500000   1.000000         0.500000     0.000000
# 75%           7.750000   1.000000         1.000000     0.750000
# max          10.000000   2.000000         1.000000     1.000000
#
#        Monthly_Energy_Consumption_kWh
# count                       10.000000
# mean                       176.000000
# std                         75.748121
# min                         90.000000
# 25%                        112.500000
# 50%                        165.000000
# 75%                        225.000000
# max                        320.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Household_ID'].plot(kind='hist', bins=20, title='Household_ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Monthly_Income_INR'].plot(kind='hist', bins=20, title='Monthly_Income_INR')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Appliance_AC'].plot(kind='hist', bins=20, title='Appliance_AC')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Appliance_Fan'].plot(kind='hist', bins=20, title='Appliance_Fan')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='Household_ID', y='Monthly_Income_INR', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='Monthly_Income_INR', y='Appliance_AC', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Appliance_AC', y='Appliance_Fan', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='Appliance_Fan', y='Appliance_Light', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['Household_ID'].plot(kind='line', figsize=(8, 4), title='Household_ID')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['Monthly_Income_INR'].plot(kind='line', figsize=(8, 4), title='Monthly_Income_INR')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['Appliance_AC'].plot(kind='line', figsize=(8, 4), title='Appliance_AC')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['Appliance_Fan'].plot(kind='line', figsize=(8, 4), title='Appliance_Fan')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
correlation_coefficient = df['Monthly_Income_INR'].corr(df['Monthly_Energy_Consumption_kWh'])
print(f"The correlation coefficient between Monthly Income and Monthly Energy Consumption is: {correlation_coefficient:.2f}")
# Out:
# The correlation coefficient between Monthly Income and Monthly Energy Consumption is: 0.98

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(df['Monthly_Income_INR'], df['Monthly_Energy_Consumption_kWh'])
plt.title('Monthly Income vs. Monthly Energy Consumption')
plt.xlabel('Monthly Income (INR)')
plt.ylabel('Monthly Energy Consumption (kWh)')
plt.grid(True)
plt.show()

# %%
print("Based on the strong positive correlation between monthly income and monthly energy consumption, several factors likely contribute to this relationship:")
print("- Higher income households may own a larger number of energy-consuming appliances (e.g., multiple AC units, larger refrigerators, dishwashers).")
print("- Higher income households might live in larger homes, requiring more energy for heating, cooling, and lighting.")
print("- Lifestyle choices in higher income households might involve more frequent use of appliances or engaging in activities that consume more energy (e.g., charging electric vehicles).")
print("\nRecommendations to address increasing energy consumption with rising income:")
print("- Promote energy-efficient appliances: Educate consumers on the long-term cost savings and environmental benefits of choosing energy-efficient models. Consider offering tax credits or rebates for purchasing such appliances.")
print("- Incentivize renewable energy adoption: Provide financial incentives (e.g., subsidies, tax breaks) for households to install solar panels or other renewable energy sources.")
print("- Educate on energy conservation practices: Launch public awareness campaigns on simple energy-saving habits, such as turning off lights, adjusting thermostats, and reducing phantom load from electronics.")
print("- Implement tiered electricity pricing: Introduce pricing structures where the cost per kWh increases significantly with higher consumption tiers, incentivizing reduced usage.")
# Out:
# Based on the strong positive correlation between monthly income and monthly energy consumption, several factors likely contribute to this relationship:
# - Higher income households may own a larger number of energy-consuming appliances (e.g., multiple AC units, larger refrigerators, dishwashers).
# - Higher income households might live in larger homes, requiring more energy for heating, cooling, and lighting.
# - Lifestyle choices in higher income households might involve more frequent use of appliances or engaging in activities that consume more energy (e.g., charging electric vehicles).
#
# Recommendations to address increasing energy consumption with rising income:
# - Promote energy-efficient appliances: Educate consumers on the long-term cost savings and environmental benefits of choosing energy-efficient models. Consider offering tax credits or rebates for purchasing such appliances.
# - Incentivize renewable energy adoption: Provide financial incentives (e.g., subsidies, tax breaks) for households to install solar panels or other renewable energy sources.
# - Educate on energy conservation practices: Launch public awareness campaigns on simple energy-saving habits, such as turning off lights, adjusting thermostats, and reducing phantom load from electronics.
# - Implement tiered electricity pricing: Introduce pricing structures where the cost per kWh increases significantly with higher consumption tiers, incentivizing reduced usage.
